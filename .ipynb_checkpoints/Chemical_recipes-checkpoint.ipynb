# %%
import pandas as pd
import numpy as np
import os
import chemdataextractor
from chemdataextractor import Document
import nltk
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer
from nltk import WordNetLemmatizer
from nltk.corpus import wordnet
import re

# %%
main = '/Users/Viktoria/Desktop/Chemicals'
os.chdir(main)

# %%
f = open('exercise_experimentals.txt', 'rb')
doc = Document.from_file(f)

# %%
#Lemmatize the texts to capture the various forms of the verb "add" and "was/were"

def get_wordnet_pos(word):
    #Map POS tag to first character lemmatize() accepts
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                    "N": wordnet.NOUN,
                    "V": wordnet.VERB,
                    "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

# %%
#Lemmatize texts to reduce the verb phrase 'is/was/were added' to 'be add'.
#To identify the chemicals that are added together, only consider the text up until the 'be add' phrase

recipes=[]

lemmatizer = WordNetLemmatizer()

for i in range(0, len(doc)):
    
    paragraph=[]
    tracker=[]
    
    for sentence in doc[i].sentences:
        words=str(sentence).split()
        text = ' '.join([lemmatizer.lemmatize(w.lower(), get_wordnet_pos(w)) for w in words])
        paragraph.append(text)
        
        #check if the addition phrase is present
        if 'add' in text or 'addition' in text:
            tracker.append(1)
        else:
            tracker.append(0)
            
    #consider the text until the last occurrence of the 'be add' phrase
    paragraph = paragraph[0:np.max(np.nonzero(tracker))+1]    
    paragraph = ' '.join([p for p in paragraph])
    recipes.append(paragraph)

# %%
#Get a list of all the chemical elements in each recipe

entities=[]

for recipe in doc:
    
    for i in range(0, len(recipe.cems)):
        entities.append(str(recipe.cems[i]).lower())

# %%
#Add words to the list which will be indicative of what is added to what

entities.extend(['add', 'and', 'to', 'be'])

# %%
#Get the important words in the order of appearance in each recipe

ordered_keywords=[]

for recipe in recipes:
    
    indices={}
    
    #check which entities appear in the text
    for entity in entities:
        if entity in recipe:
            start = recipe.index(entity)
            end = recipe.index(entity)+len(entity)
            indices[entity]=start, end
            
                
    #sort these by the order of appearance
    #indices = dict(sorted(indices.items(), key=lambda item: item[1]))
    #ordered_keywords.append(list(indices.keys()))

# %%
indices
# Out:
# {'dmso': (79, 83),
#  'thf': (75, 78),
#  'nah': (16, 19),
#  'ethylene glycol': (150, 165),
#  'tributyl(iodomethyl)stannane': (326, 354),
#  'add': (138, 141),
#  'to': (107, 109),
#  'be': (99, 101)}

# %%
recipe[138:141]
# Out:
# 'add'

# %%
import pandas as pd
from tqdm import tqdm
import spacy
from spacy.tokens import DocBin

nlp = spacy.load("en_core_web_sm") # load a new spacy model
db = DocBin() # create a DocBin object

doc1 = nlp(recipes[-2]) # create doc object from text
ents = []
for key,value in indices.items(): # add character indexes
    span = doc1.char_span(value[0], value[1], label=key, alignment_mode="expand")
    if span is None:
        print('none')
    else:
        ents.append(span)
          
doc1.ents = ents # label the text with the ents
db.add(doc1)

#db.to_disk("./train.spacy") # save the docbin object
# Out:
# none

# %%
doc1.is_tagged
# Out:
# <ipython-input-97-6e898ba2f198>:1: DeprecationWarning: [W107] The property `Doc.is_tagged` is deprecated. Use `Doc.has_annotation("TAG")` instead.
#   doc1.is_tagged
# True

# %%
import spacy
from spacy import displacy

displacy.render(doc1, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9343ff6f5d194282a46af62c359f7ffb-0" class="displacy" width="7925" height="924.5" direction="ltr" style="max-width: none; height: 924.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
# ...

# %%
for token in doc1:
    print(token.text, token.dep_)
# Out:
# to prep
# a det
# flame pobj
# dry amod
# two nummod
# necked amod
# round amod
# bottom amod
# flask appos
# , punct
# equip ROOT
# with prep
# a det
# stopcock pobj
# , punct
# be aux
# add conj
# 4b dobj
# ( punct
# 189 nummod
# mg appos
# , punct
# 0.500 nummod
# mmol appos
# , punct
# 1 nummod
# eq appos
# . punct
# ) punct
# and cc
# the det
# iridium(i nmod
# ) punct
# catalyst conj
# ( punct
# 0.00325 nummod
# mmol appos
# , punct
# 6.5 nummod
# mol% appos
# ) punct
# . punct
# to prep
# this nsubjpass
# be auxpass
# add ROOT
# dcm dobj
# ( punct
# 14.0 nummod
# ml appos
# ) punct
# and cc
# the det
# solution ROOT
# cool amod
# to prep
# 0 nummod
# ° pobj
# c. appos

# %%
### Open a list for the words that have 'carefully', 'slowly', 'dropwise'
